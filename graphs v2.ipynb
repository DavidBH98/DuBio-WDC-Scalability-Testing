# %%
import matplotlib.pyplot as plt
import numpy as np
 
#x = np.array([1, 2, 3, 4])
#y = x*2
 
# first plot with X and Y data
#plt.plot(x, y)
 
x1 = [100, 250, 500, 750, 1000, 1500, 2000, 2500, 3000, 3500, 4000]
y21 = [2.607120102, 2.46356157, 3.626670478, 4.252319824, 7.238002767,
       7.4039104, 15.79610216, 17.41652571, 17.20216523, 16.04380221,
       29.38019165]
y22 = [2.275193068, 3.270054725, 5.064180801, 5.550551048, 12.05373964,
       9.824515779, 22.042623, 22.92492917, 24.28132668, 23.6317467,
       43.99574092]
y23 = [2.298295204, 2.247885946, 2.874223602, 2.76487524, 4.537638245,
       4.706713514, 7.694799358, 9.020254137, 9.010760153, 9.967202,
       16.32789958]
y24 = [2.266847252, 3.450392635, 5.679903234, 5.326002238, 14.32335074,
       14.55682927, 29.30434197, 29.42988092, 26.04497591, 26.72770226,
       46.40733095]

y31 = [2.721979007, 4.136073961, 7.176017497, 7.101293909, 15.11541022,
       12.71410955, 22.76106075, 36.26241109, 26.40393144, 36.36182937, 
       52.43357387]
y32 = [4.567603748, 8.539086419, 17.73897404, 9.987445252, 38.03498261,
       22.6982209, 43.19093243, 69.13706567, 45.66324167, 55.69452703,
       83.47720335]
y33 = [2.271001826, 2.423518354, 4.492409118, 4.711667535, 10.11370649,
       8.381662729, 13.93538149, 21.19811857, 16.66760194, 22.73109429,
       36.57747955]
y34 = [4.351157848, 6.45694318, 11.08471695, 7.601188486, 23.0832481,
       20.65858217, 29.18546096, 37.22324581, 30.28438354, 41.00112231,
       56.34817402]

y41 = [5.330846425, 11.03032984, 24.73584418, 35.70220737, 54.40267029,
       72.24553821, 99.13970717, 115.9968957, 136.2595098, 184.8218856,
       200.3819841]
y42 = [12.12654788, 20.32441867, 49.26087838, 64.82803327, 88.33493983,
       121.851145, 184.1884215, 228.635843, 270.6249551, 357.7474779,
       397.466291]
y43 = [2.527958469, 3.66855626, 6.599146095, 10.49501887, 15.05035037,
       23.30116176, 33.89001635, 43.27640406, 47.4224882, 62.13280143,
       68.92347267]
y44 = [5.361886764, 6.072329875, 13.64149003, 22.58705627, 29.37793101,
       38.69819172, 54.0570608, 59.26549817, 66.83953156, 98.85188587,
       105.3550153]

d231 = [1.044055855, 1.678900179, 1.978679216, 1.66998114, 2.088339934,
        1.71721548, 1.440928941, 2.082069162, 1.534919069, 2.266409726,
        1.784657312]
d232 = [2.007567539, 2.611297711, 3.502831897, 1.79936103, 3.155450818,
        2.310365356, 1.959427988, 3.015802804, 1.880590887, 2.356767265,
        1.89739248]
d233 = [0.9881245116, 1.078132259, 1.562999175, 1.704115783, 2.228848124,
        1.780788804, 1.811012977, 2.350057797, 1.849744268, 2.280589306,
        2.240182785]
d234 = [1.919475538, 1.871364758, 1.951567922, 1.427184621, 1.611581572,
        1.419167718, 0.9959432288, 1.264811295, 1.162772569, 1.534030943,
        1.214208464]

d341 = [1.958445091, 2.666859912, 3.447015589, 5.027563685, 3.599152752,
        5.682312074, 4.355671656, 3.198819169, 5.160576565, 5.082854433,
        3.821635058]
d342 = [2.654903654, 2.380163131, 2.776985764, 6.490952554, 2.322465629,
        5.368312589, 4.264515979, 3.306993735, 5.926538397, 6.423386587,
        4.761375262]
d343 = [1.113146824, 1.513731577, 1.468954835, 2.227453188, 1.488114213,
        2.780016628, 2.431940336, 2.041520992, 2.84518963, 2.733383648,
        1.884314434]
d344 = [1.232289646, 0.9404341506, 1.230657498, 2.971516403, 1.272694851,
        1.873225926, 1.852191434, 1.59216363, 2.207062642, 2.41095561,
        1.869714807]
 
# second plot with x1 and y1 data
#plt.plot(x1, y21, label="query 1 s2")
#plt.plot(x1, y22, label="query 2 s2")
#plt.plot(x1, y23, label="query 3 s2")
#plt.plot(x1, y24, label="query 4 s2")
#plt.plot(x1, y31, label="query 1 s3")
#plt.plot(x1, y32, label="query 2 s3")
#plt.plot(x1, y33, label="query 3 s3")
#plt.plot(x1, y34, label="query 4 s3")
#plt.plot(x1, y41, label="query 1 s4")
#plt.plot(x1, y42, label="query 2 s4")
#plt.plot(x1, y43, label="query 3 s4")
#plt.plot(x1, y44, label="query 4 s4")
#plt.plot(x1, d231, label="query 1")
#plt.plot(x1, d232, label="query 2")
#plt.plot(x1, d233, label="query 3")
#plt.plot(x1, d234, label="query 4")
plt.plot(x1, d341, label="query 1")
plt.plot(x1, d342, label="query 2")
plt.plot(x1, d343, label="query 3")
plt.plot(x1, d344, label="query 4")
plt.legend()
 
plt.xlabel("Number of Clusters")
plt.ylabel("Relative Difference in Time")
plt.show()
